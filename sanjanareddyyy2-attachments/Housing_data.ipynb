# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from prince import MCA
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
# Load data set
df = pd.read_csv('train.csv')
df = df.drop('Id', axis = 1)

# Remove columns that have too many missing values
df = df.drop(df.columns[df.isnull().sum() > 30], axis = 1)

# Remove missing values
df.dropna(inplace = True)

df
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0             60       RL     8450   Pave      Reg         Lvl    AllPub
# 1             20       RL     9600   Pave      Reg         Lvl    AllPub
# 2             60       RL    11250   Pave      IR1         Lvl    AllPub
# 3             70       RL     9550   Pave      IR1         Lvl    AllPub
# 4             60       RL    14260   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 1455          60       RL     7917   Pave      Reg         Lvl    AllPub
# 1456          20       RL    13175   Pave      Reg         Lvl    AllPub
# 1457          70       RL     9042   Pave      Reg         Lvl    AllPub
# 1458          20       RL     9717   Pave      Reg         Lvl    AllPub
# 1459          20       RL     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch  \
# 0       Inside       Gtl      CollgCr  ...             0         0
# 1          FR2       Gtl      Veenker  ...             0         0
# 2       Inside       Gtl      CollgCr  ...             0         0
# 3       Corner       Gtl      Crawfor  ...           272         0
# 4          FR2       Gtl      NoRidge  ...             0         0
# ...        ...       ...          ...  ...           ...       ...
# 1455    Inside       Gtl      Gilbert  ...             0         0
# 1456    Inside       Gtl       NWAmes  ...             0         0
# 1457    Inside       Gtl      Crawfor  ...             0         0
# 1458    Inside       Gtl        NAmes  ...           112         0
# 1459    Inside       Gtl      Edwards  ...             0         0
#
#      ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition  \
# 0              0        0        0       2    2008        WD        Normal
# 1              0        0        0       5    2007        WD        Normal
# 2              0        0        0       9    2008        WD        Normal
# 3              0        0        0       2    2006        WD       Abnorml
# 4              0        0        0      12    2008        WD        Normal
# ...          ...      ...      ...     ...     ...       ...           ...
# 1455           0        0        0       8    2007        WD        Normal
# 1456           0        0        0       2    2010        WD        Normal
# 1457           0        0     2500       5    2010        WD        Normal
# 1458           0        0        0       4    2010        WD        Normal
# 1459           0        0        0       6    2008        WD        Normal
#
#      SalePrice
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# ...        ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
#
# [1451 rows x 64 columns]

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
# # Step 1: Remove columns with too many missing values
# threshold_missing_values = 0.3  # Adjust this threshold as needed

# # Calculate the percentage of missing values for each column
# missing_percentage = df.isnull().mean()

# # Identify columns exceeding the threshold
# columns_to_drop = missing_percentage[missing_percentage > threshold_missing_values].index

# # Drop the identified columns
# df = df.drop(columns=columns_to_drop)

# # Step 2: Remove remaining missing values
# # For simplicity, you can drop rows with any missing values
# df = df.dropna()

# %%
# Check for NaN or infinite values in the DataFrame
print(df.isnull().sum())  # Display NaN counts per column
print(df.isin([np.inf, -np.inf]).sum())  # Display counts of infinite values per column

# Remove rows with NaN or infinite values
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1451 entries, 0 to 1459
# Data columns (total 64 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1451 non-null   int64
#  1   MSZoning       1451 non-null   object
#  2   LotArea        1451 non-null   int64
#  3   Street         1451 non-null   object
#  4   LotShape       1451 non-null   object
#  5   LandContour    1451 non-null   object
#  6   Utilities      1451 non-null   object
#  7   LotConfig      1451 non-null   object
#  8   LandSlope      1451 non-null   object
#  9   Neighborhood   1451 non-null   object
#  10  Condition1     1451 non-null   object
#  11  Condition2     1451 non-null   object
#  12  BldgType       1451 non-null   object
#  13  HouseStyle     1451 non-null   object
#  14  OverallQual    1451 non-null   int64
#  15  OverallCond    1451 non-null   int64
#  16  YearBuilt      1451 non-null   int64
#  17  YearRemodAdd   1451 non-null   int64
#  18  RoofStyle      1451 non-null   object
#  19  RoofMatl       1451 non-null   object
#  20  Exterior1st    1451 non-null   object
#  21  Exterior2nd    1451 non-null   object
#  22  MasVnrType     1451 non-null   object
#  23  MasVnrArea     1451 non-null   float64
#  24  ExterQual      1451 non-null   object
#  25  ExterCond      1451 non-null   object
#  26  Foundation     1451 non-null   object
#  27  BsmtFinSF1     1451 non-null   int64
#  28  BsmtFinSF2     1451 non-null   int64
#  29  BsmtUnfSF      1451 non-null   int64
#  30  TotalBsmtSF    1451 non-null   int64
#  31  Heating        1451 non-null   object
#  32  HeatingQC      1451 non-null   object
#  33  CentralAir     1451 non-null   object
#  34  Electrical     1451 non-null   object
#  35  1stFlrSF       1451 non-null   int64
#  36  2ndFlrSF       1451 non-null   int64
#  37  LowQualFinSF   1451 non-null   int64
#  38  GrLivArea      1451 non-null   int64
#  39  BsmtFullBath   1451 non-null   int64
#  40  BsmtHalfBath   1451 non-null   int64
#  41  FullBath       1451 non-null   int64
#  42  HalfBath       1451 non-null   int64
#  43  BedroomAbvGr   1451 non-null   int64
#  44  KitchenAbvGr   1451 non-null   int64
#  45  KitchenQual    1451 non-null   object
#  46  TotRmsAbvGrd   1451 non-null   int64
#  47  Functional     1451 non-null   object
#  48  Fireplaces     1451 non-null   int64
#  49  GarageCars     1451 non-null   int64
#  50  GarageArea     1451 non-null   int64
#  51  PavedDrive     1451 non-null   object
#  52  WoodDeckSF     1451 non-null   int64
#  53  OpenPorchSF    1451 non-null   int64
#  54  EnclosedPorch  1451 non-null   int64
#  55  3SsnPorch      1451 non-null   int64
#  56  ScreenPorch    1451 non-null   int64
#  57  PoolArea       1451 non-null   int64
#  58  MiscVal        1451 non-null   int64
#  59  MoSold         1451 non-null   int64
#  60  YrSold         1451 non-null   int64
#  61  SaleType       1451 non-null   object
#  62  SaleCondition  1451 non-null   object
#  63  SalePrice      1451 non-null   int64
# dtypes: float64(1), int64(34), object(29)
# memory usage: 736.8+ KB

# %% [markdown]
# 1. Apply MCA onto the data set:

# %%
# Step 1: Split the data into training and testing sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=100)

# %%
# Step 2: Separate numerical and categorical features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns

# %%
'''
This is the script you can use to check the categorical features between training and testing sets.
You can apply this code after you can done the train/test split, as well as separation of numerical
and categorical features.
'''
X_train_cat = train_data[categorical_features]
X_test_cat = test_data[categorical_features]

# Suppose your categorical features in training set is called X_train_cat.
# Suppose your categorical features in testing set is called X_test_set.
# Make sure the training feature and testing feature has same number of levels
keep = X_train_cat.nunique() == X_test_cat.nunique()
X_train_cat = X_train_cat[X_train_cat.columns[keep]]
X_test_cat = X_test_cat[X_test_cat.columns[keep]]

# For categorical features that have same levels, make sure the classes are the same
keep = []
for i in range(X_train_cat.shape[1]):
    keep.append(all(np.sort(X_train_cat.iloc[:,i].unique()) == np.sort(X_test_cat.iloc[:,i].unique())))
X_train_cat = X_train_cat[X_train_cat.columns[keep]]
X_test_cat = X_test_cat[X_test_cat.columns[keep]]

# %%
# Step 3: Ensure that both train and test datasets have the same set of levels for each categorical variable
for cat_col in categorical_features:
    train_levels = set(train_data[cat_col].unique())
    test_levels = set(test_data[cat_col].unique())
    all_levels = train_levels.union(test_levels)
    train_data[cat_col] = train_data[cat_col].astype('category').cat.set_categories(all_levels)
    test_data[cat_col] = test_data[cat_col].astype('category').cat.set_categories(all_levels)

# %%
# Step 4: Apply PCA on numerical features
pca = PCA(n_components=2)
train_pca_result = pca.fit_transform(train_data[numerical_features])
test_pca_result = pca.transform(test_data[numerical_features])

# %%
train_pca_result.shape
# Out:
# (1160, 2)

# %%
X_train_cat
# Out:
#      MSZoning LotShape LandContour LotConfig LandSlope BldgType MasVnrType  \
# 624        RL      Reg         Lvl    Inside       Gtl     1Fam       None
# 592        RL      Reg         Lvl    Inside       Gtl     1Fam       None
# 48         RM      Reg         Lvl    Inside       Gtl   2fmCon       None
# 1070       RL      Reg         Lvl    Inside       Gtl     1Fam    BrkFace
# 1234       RH      Reg         Bnk    Inside       Gtl     1Fam       None
# ...       ...      ...         ...       ...       ...      ...        ...
# 805        RL      IR1         Lvl       FR2       Gtl     1Fam      Stone
# 53         RL      IR1         Low    Inside       Gtl     1Fam       None
# 351        RL      IR1         Low    Inside       Mod     1Fam       None
# 79         RM      Reg         Lvl    Corner       Gtl     1Fam       None
# 795        RL      Reg         Lvl    Inside       Gtl     1Fam    BrkFace
#
#      ExterQual CentralAir KitchenQual PavedDrive
# 624         TA          Y          TA          Y
# 592         TA          Y          TA          Y
# 48          TA          Y          TA          N
# 1070        TA          Y          TA          Y
# 1234        TA          N          TA          N
# ...        ...        ...         ...        ...
# 805         Gd          Y          Ex          Y
# 53          Gd          Y          Gd          Y
# 351         TA          Y          Gd          Y
# 79          TA          Y          TA          Y
# 795         TA          Y          TA          Y
#
# [1160 rows x 11 columns]

# %%
one_hot = pd.get_dummies(train_data[categorical_features])
one_hot
# Out:
#       MSZoning_FV  MSZoning_C (all)  MSZoning_RH  MSZoning_RM  MSZoning_RL  \
# 449             0                 0            0            1            0
# 901             0                 0            0            0            1
# 550             0                 0            0            0            1
# 1115            0                 0            0            0            1
# 226             0                 0            0            0            1
# ...           ...               ...          ...          ...          ...
# 1071            0                 0            0            0            1
# 67              0                 0            0            0            1
# 466             0                 0            0            0            1
# 103             0                 0            0            0            1
# 1060            0                 0            0            0            1
#
#       Street_Grvl  Street_Pave  LotShape_IR3  LotShape_IR2  LotShape_IR1  ...  \
# 449             0            1             0             0             0  ...
# 901             0            1             0             0             1  ...
# 550             0            1             0             0             0  ...
# 1115            0            1             0             0             0  ...
# 226             0            1             0             0             1  ...
# ...           ...          ...           ...           ...           ...  ...
# 1071            0            1             0             0             0  ...
# 67              0            1             0             0             1  ...
# 466             0            1             0             0             0  ...
# 103             0            1             0             0             1  ...
# 1060            0            1             0             0             0  ...
#
#       SaleType_ConLD  SaleType_Oth  SaleType_Con  SaleType_ConLw  \
# 449                0             0             0               0
# 901                0             0             0               0
# 550                0             0             0               0
# 1115               0             0             0               0
# 226                0             0             0               0
# ...              ...           ...           ...             ...
# 1071               0             0             0               0
# 67                 0             0             0               0
# 466                0             0             0               0
# 103                0             0             0               0
# 1060               0             0             0               0
#
#       SaleCondition_Abnorml  SaleCondition_Normal  SaleCondition_Partial  \
# 449                       0                     1                      0
# 901                       0                     1                      0
# 550                       1                     0                      0
# 1115                      0                     0                      1
# 226                       1                     0                      0
# ...                     ...                   ...                    ...
# 1071                      0                     1                      0
# 67                        0                     1                      0
# 466                       0                     1                      0
# 103                       0                     1                      0
# 1060                      0                     1                      0
#
#       SaleCondition_Family  SaleCondition_AdjLand  SaleCondition_Alloca
# 449                      0                      0                     0
# 901                      0                      0                     0
# 550                      0                      0                     0
# 1115                     0                      0                     0
# 226                      0                      0                     0
# ...                    ...                    ...                   ...
# 1071                     0                      0                     0
# 67                       0                      0                     0
# 466                      0                      0                     0
# 103                      0                      0                     0
# 1060                     0                      0                     0
#
# [875 rows x 223 columns]

# %%
# Step 5: Apply MCA on categorical features
mca = MCA(n_components=2)
train_mca_result = mca.fit_transform(X_train_cat)
test_mca_result = mca.transform(X_test_cat)

# %%
train_pca_df = pd.DataFrame(train_pca_result, columns=['pca_1', 'pca_2'])
test_pca_df = pd.DataFrame(test_pca_result, columns=['pca_1', 'pca_2'])

# %%
train_pca_df
# Out:
#               pca_1         pca_2
# 0     -15953.486168    392.959408
# 1     -43223.749866  -2459.400938
# 2     -68280.915342  -3739.495588
# 3     -46096.773033   1195.063397
# 4     -51145.742408   -260.485529
# ...             ...           ...
# 1155   46602.917621     93.784026
# 1156  205150.038968  32618.919571
# 1157    8704.845484  -5585.607817
# 1158  -71073.465811   2343.578482
# 1159  -10179.126434  -1812.701639
#
# [1160 rows x 2 columns]

# %%
test_mca_result
# Out:
#              0         1
# 357   0.296526 -0.507883
# 824  -0.375315 -0.421014
# 369  -0.145580  0.159588
# 291   2.200111  0.146006
# 134   0.060756  0.090473
# ...        ...       ...
# 1424  0.190777 -0.102245
# 1130 -0.012936 -0.108776
# 899   0.190777 -0.102245
# 932  -0.790089  0.193782
# 573   0.060756  0.090473
#
# [291 rows x 2 columns]

# %%
# Resetting indices
train_mca_result = train_mca_result.reset_index(drop=True)
test_mca_result = test_mca_result.reset_index(drop=True)

# %%
# Concatenate the PCA and MCA results
X_train = pd.concat([train_pca_df, train_mca_result], axis=1)
X_test = pd.concat([test_pca_df, test_mca_result], axis= 1, ignore_index=True)

# %%
# Perform regression using the reduced features
model = Ridge()
model.fit(X_train, train_data['SalePrice'])

# Predict and evaluate on the testing set
y_pred = model.predict(X_test)
mse = mean_squared_error(test_data['SalePrice'], y_pred)
print(f'Mean Squared Error (PCA + MCA): {mse}')
# Out:
# Mean Squared Error (PCA + MCA): 6.8229257761117
# c:\Users\surit\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
